# %%
# !pip install ultralyticsplus==0.0.28 ultralytics==8.0.43 mplfinance

# %%
import pandas as pd
import mplfinance as mpf
from ultralyticsplus import YOLO
import cv2
import glob
import os
from google.colab.patches import cv2_imshow

# %%
# Load and preprocess data
def load_and_preprocess_data(file_path, num_records=500):
    data = pd.read_csv(file_path).tail(num_records)
    data[['open', 'high', 'low', 'close']] = data[['open', 'high', 'low', 'close']].astype(float)
    data['time'] = pd.to_datetime(data['time'])
    data.set_index('time', inplace=True)
    return data

# Generate candlestick charts
def generate_candlestick_charts(data, window_size, save_dir='/content/images'):
    if not os.path.exists(save_dir):
      os.makedirs(save_dir)
    max_time_gap = pd.Timedelta(minutes=10)  # Define maximum allowed time gap
    for i in range(0, len(data), window_size):
        ohlc = data.iloc[i:i + window_size]

        # Check for time gaps in the subset data
        ohlc['time_gap'] = ohlc.index.to_series().diff()
        if any(ohlc['time_gap'] > max_time_gap):
            print(f"Skipping chart from index {i} to {i + window_size - 1} due to time gap greater than 10 minutes.")
            continue

        if len(ohlc) < window_size:
            break

        # Generate chart name based on DataFrame length and data range
        start_time = ohlc.index[0].strftime('%Y-%m-%d %H:%M')
        end_time = ohlc.index[-1].strftime('%Y-%m-%d %H:%M')
        chart_name = f'candlestick_chart_{len(data)}_{start_time}_to_{end_time}.png'

        mpf.plot(ohlc, type='candle', style='charles', title=f'Candlestick Chart ({start_time} to {end_time})',
                 ylabel='Price', volume=False, savefig=f'{save_dir}/{chart_name}')

# Detect patterns in images using YOLO and save detected patterns
def detect_patterns_in_images(image_dir, model, save_dir='/content/detected_patterns'):
    # Create the directory if it doesn't exist
    if not os.path.exists(save_dir):
        os.makedirs(save_dir)

    image_paths = glob.glob(f'{image_dir}/*.png')
    for image_path in image_paths:
        image = cv2.imread(image_path)
        results = model(image)

        # Only save and show images if patterns are detected
        if len(results[0].boxes) > 0:  # Check if any detections were made
            print(f"Pattern detected in {image_path}")
            annotated_image = results[0].plot()

            # Save the annotated image to the detected_patterns directory
            image_name = os.path.basename(image_path)
            save_path = os.path.join(save_dir, f'detected_{image_name}')
            cv2.imwrite(save_path, annotated_image)
            print(f"Saved detected pattern to {save_path}")

            # Display the annotated image
            cv2_imshow(annotated_image)
            cv2.waitKey(0)
        else:
            print(f"No pattern detected in {image_path}")

# Load and preprocess data
data = load_and_preprocess_data('/content/XAUUSD_M5.csv')

# Define window sizes
window_sizes = [24, 50, 72]  # 2 hours, 4.1 hours, 6 hours

# Generate candlestick charts for each window size
for window_size in window_sizes:
    generate_candlestick_charts(data, window_size)

# Load YOLO model
model = YOLO('foduucom/stockmarket-pattern-detection-yolov8')
model.overrides['conf'] = 0.25  # NMS confidence threshold
model.overrides['iou'] = 0.45  # NMS IoU threshold
model.overrides['agnostic_nms'] = False  # NMS class-agnostic
model.overrides['max_det'] = 1000  # maximum number of detections per image

# Detect patterns in generated images and save detected patterns
detect_patterns_in_images('/content/images', model)
# Out:
# <ipython-input-4-15c6e13f898d>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ohlc['time_gap'] = ohlc.index.to_series().diff()
# <ipython-input-4-15c6e13f898d>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ohlc['time_gap'] = ohlc.index.to_series().diff()
# <ipython-input-4-15c6e13f898d>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ohlc['time_gap'] = ohlc.index.to_series().diff()
# <ipython-input-4-15c6e13f898d>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ohlc['time_gap'] = ohlc.index.to_series().diff()
# <ipython-input-4-15c6e13f898d>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ohlc['time_gap'] = ohlc.index.to_series().diff()
# <ipython-input-4-15c6e13f898d>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ohlc['time_gap'] = ohlc.index.to_series().diff()
# <ipython-input-4-15c6e13f898d>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ohlc['time_gap'] = ohlc.index.to_series().diff()
# <ipython-input-4-15c6e13f898d>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ohlc['time_gap'] = ohlc.index.to_series().diff()
# <ipython-input-4-15c6e13f898d>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ohlc['time_gap'] = ohlc.index.to_series().diff()
# <ipython-input-4-15c6e13f898d>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ohlc['time_gap'] = ohlc.index.to_series().diff()
# <ipython-input-4-15c6e13f898d>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ohlc['time_gap'] = ohlc.index.to_series().diff()
# Skipping chart from index 216 to 239 due to time gap greater than 10 minutes.
# <ipython-input-4-15c6e13f898d>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ohlc['time_gap'] = ohlc.index.to_series().diff()
# <ipython-input-4-15c6e13f898d>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ohlc['time_gap'] = ohlc.index.to_series().diff()
# <ipython-input-4-15c6e13f898d>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ohlc['time_gap'] = ohlc.index.to_series().diff()
# <ipython-input-4-15c6e13f898d>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ohlc['time_gap'] = ohlc.index.to_series().diff()
# <ipython-input-4-15c6e13f898d>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ohlc['time_gap'] = ohlc.index.to_series().diff()
# <ipython-input-4-15c6e13f898d>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ohlc['time_gap'] = ohlc.index.to_series().diff()
# <ipython-input-4-15c6e13f898d>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ohlc['time_gap'] = ohlc.index.to_series().diff()
# <ipython-input-4-15c6e13f898d>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ohlc['time_gap'] = ohlc.index.to_series().diff()
# <ipython-input-4-15c6e13f898d>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ohlc['time_gap'] = ohlc.index.to_series().diff()
# <ipython-input-4-15c6e13f898d>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ohlc['time_gap'] = ohlc.index.to_series().diff()
# <ipython-input-4-15c6e13f898d>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ohlc['time_gap'] = ohlc.index.to_series().diff()
# <ipython-input-4-15c6e13f898d>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ohlc['time_gap'] = ohlc.index.to_series().diff()
# <ipython-input-4-15c6e13f898d>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ohlc['time_gap'] = ohlc.index.to_series().diff()
# <ipython-input-4-15c6e13f898d>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ohlc['time_gap'] = ohlc.index.to_series().diff()
# <ipython-input-4-15c6e13f898d>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ohlc['time_gap'] = ohlc.index.to_series().diff()
# <ipython-input-4-15c6e13f898d>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ohlc['time_gap'] = ohlc.index.to_series().diff()
# <ipython-input-4-15c6e13f898d>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ohlc['time_gap'] = ohlc.index.to_series().diff()
# Skipping chart from index 200 to 249 due to time gap greater than 10 minutes.
# <ipython-input-4-15c6e13f898d>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ohlc['time_gap'] = ohlc.index.to_series().diff()
# <ipython-input-4-15c6e13f898d>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ohlc['time_gap'] = ohlc.index.to_series().diff()
# <ipython-input-4-15c6e13f898d>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ohlc['time_gap'] = ohlc.index.to_series().diff()
# <ipython-input-4-15c6e13f898d>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ohlc['time_gap'] = ohlc.index.to_series().diff()
# <ipython-input-4-15c6e13f898d>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ohlc['time_gap'] = ohlc.index.to_series().diff()
# <ipython-input-4-15c6e13f898d>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ohlc['time_gap'] = ohlc.index.to_series().diff()
# <ipython-input-4-15c6e13f898d>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ohlc['time_gap'] = ohlc.index.to_series().diff()
# <ipython-input-4-15c6e13f898d>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ohlc['time_gap'] = ohlc.index.to_series().diff()
# Skipping chart from index 216 to 287 due to time gap greater than 10 minutes.
# <ipython-input-4-15c6e13f898d>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ohlc['time_gap'] = ohlc.index.to_series().diff()
# <ipython-input-4-15c6e13f898d>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ohlc['time_gap'] = ohlc.index.to_series().diff()
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/161 [00:00<?, ?B/s]
# best.pt:   0%|          | 0.00/134M [00:00<?, ?B/s]
# /usr/local/lib/python3.11/dist-packages/ultralytics/nn/tasks.py:340: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(file, map_location='cpu'), file  # load
# Ultralytics YOLOv8.0.43 🚀 Python-3.11.11 torch-2.5.1+cu124 CPU
# Model summary (fused): 168 layers, 11127906 parameters, 0 gradients, 28.4 GFLOPs
#
# 0: 480x640 (no detections), 1020.1ms
# Speed: 3.9ms preprocess, 1020.1ms inference, 15.5ms postprocess per image at shape (1, 3, 640, 640)
# No pattern detected in /content/images/candlestick_chart_500_2024-12-26 02:35_to_2024-12-26 04:30.png
# 0: 480x640 (no detections), 705.5ms
# Speed: 1.1ms preprocess, 705.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
# No pattern detected in /content/images/candlestick_chart_500_2024-12-27 05:45_to_2024-12-27 07:40.png
# 0: 480x640 (no detections), 708.1ms
# Speed: 0.9ms preprocess, 708.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
# No pattern detected in /content/images/candlestick_chart_500_2024-12-26 02:35_to_2024-12-26 06:40.png
# 0: 480x640 (no detections), 611.9ms
# Speed: 1.1ms preprocess, 611.9ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# No pattern detected in /content/images/candlestick_chart_500_2024-12-26 12:35_to_2024-12-26 14:30.png
# 0: 480x640 (no detections), 448.2ms
# Speed: 0.9ms preprocess, 448.2ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# No pattern detected in /content/images/candlestick_chart_500_2024-12-26 04:35_to_2024-12-26 06:30.png
# 0: 480x640 1 M_Head, 434.0ms
# Speed: 1.0ms preprocess, 434.0ms inference, 22.6ms postprocess per image at shape (1, 3, 640, 640)
# Pattern detected in /content/images/candlestick_chart_500_2024-12-27 04:45_to_2024-12-27 08:50.png
# Saved detected pattern to /content/detected_patterns/detected_candlestick_chart_500_2024-12-27 04:45_to_2024-12-27 08:50.png
# <PIL.Image.Image image mode=RGB size=800x575>
# 0: 480x640 (no detections), 446.9ms
# Speed: 1.0ms preprocess, 446.9ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# No pattern detected in /content/images/candlestick_chart_500_2024-12-26 08:35_to_2024-12-26 14:30.png
# 0: 480x640 1 Head and shoulders bottom, 448.0ms
# Speed: 1.1ms preprocess, 448.0ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
# Pattern detected in /content/images/candlestick_chart_500_2024-12-26 06:45_to_2024-12-26 10:50.png
# Saved detected pattern to /content/detected_patterns/detected_candlestick_chart_500_2024-12-26 06:45_to_2024-12-26 10:50.png
# <PIL.Image.Image image mode=RGB size=800x575>
# 0: 480x640 (no detections), 447.1ms
# Speed: 1.1ms preprocess, 447.1ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# No pattern detected in /content/images/candlestick_chart_500_2024-12-26 08:35_to_2024-12-26 10:30.png
# 0: 480x640 (no detections), 471.2ms
# Speed: 3.2ms preprocess, 471.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
# No pattern detected in /content/images/candlestick_chart_500_2024-12-27 09:45_to_2024-12-27 11:40.png
# 0: 480x640 (no detections), 430.9ms
# Speed: 1.2ms preprocess, 430.9ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# No pattern detected in /content/images/candlestick_chart_500_2024-12-27 01:45_to_2024-12-27 03:40.png
# 0: 480x640 (no detections), 432.1ms
# Speed: 1.3ms preprocess, 432.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
# No pattern detected in /content/images/candlestick_chart_500_2024-12-26 23:45_to_2024-12-27 01:40.png
# 0: 480x640 1 W_Bottom, 463.2ms
# Speed: 3.2ms preprocess, 463.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Pattern detected in /content/images/candlestick_chart_500_2024-12-27 08:55_to_2024-12-27 13:00.png
# Saved detected pattern to /content/detected_patterns/detected_candlestick_chart_500_2024-12-27 08:55_to_2024-12-27 13:00.png
# <PIL.Image.Image image mode=RGB size=800x575>
# 0: 480x640 (no detections), 455.2ms
# Speed: 1.0ms preprocess, 455.2ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
# No pattern detected in /content/images/candlestick_chart_500_2024-12-27 07:45_to_2024-12-27 09:40.png
# 0: 480x640 (no detections), 446.7ms
# Speed: 1.1ms preprocess, 446.7ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# No pattern detected in /content/images/candlestick_chart_500_2024-12-26 10:35_to_2024-12-26 12:30.png
# 0: 480x640 (no detections), 420.0ms
# Speed: 1.0ms preprocess, 420.0ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# No pattern detected in /content/images/candlestick_chart_500_2024-12-27 11:45_to_2024-12-27 13:40.png
# 0: 480x640 1 Head and shoulders top, 455.7ms
# Speed: 3.0ms preprocess, 455.7ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
# Pattern detected in /content/images/candlestick_chart_500_2024-12-27 09:45_to_2024-12-27 15:40.png
# Saved detected pattern to /content/detected_patterns/detected_candlestick_chart_500_2024-12-27 09:45_to_2024-12-27 15:40.png
# <PIL.Image.Image image mode=RGB size=800x575>
# 0: 480x640 1 M_Head, 432.5ms
# Speed: 1.1ms preprocess, 432.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Pattern detected in /content/images/candlestick_chart_500_2024-12-27 17:15_to_2024-12-27 21:20.png
# Saved detected pattern to /content/detected_patterns/detected_candlestick_chart_500_2024-12-27 17:15_to_2024-12-27 21:20.png
# <PIL.Image.Image image mode=RGB size=800x575>
# 0: 480x640 (no detections), 462.2ms
# Speed: 1.0ms preprocess, 462.2ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# No pattern detected in /content/images/candlestick_chart_500_2024-12-27 03:45_to_2024-12-27 05:40.png
# 0: 480x640 (no detections), 432.9ms
# Speed: 1.1ms preprocess, 432.9ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# No pattern detected in /content/images/candlestick_chart_500_2024-12-26 10:55_to_2024-12-26 15:00.png
# 0: 480x640 1 W_Bottom, 466.5ms
# Speed: 1.0ms preprocess, 466.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
# Pattern detected in /content/images/candlestick_chart_500_2024-12-26 14:35_to_2024-12-26 20:30.png
# Saved detected pattern to /content/detected_patterns/detected_candlestick_chart_500_2024-12-26 14:35_to_2024-12-26 20:30.png
# <PIL.Image.Image image mode=RGB size=800x575>
# 0: 480x640 (no detections), 420.8ms
# Speed: 1.0ms preprocess, 420.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# No pattern detected in /content/images/candlestick_chart_500_2024-12-26 16:35_to_2024-12-26 18:30.png
# 0: 480x640 1 W_Bottom, 464.8ms
# Speed: 3.3ms preprocess, 464.8ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
# Pattern detected in /content/images/candlestick_chart_500_2024-12-26 15:05_to_2024-12-26 19:10.png
# Saved detected pattern to /content/detected_patterns/detected_candlestick_chart_500_2024-12-26 15:05_to_2024-12-26 19:10.png
# <PIL.Image.Image image mode=RGB size=800x575>
# 0: 480x640 1 M_Head, 1 W_Bottom, 446.2ms
# Speed: 3.0ms preprocess, 446.2ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
# Pattern detected in /content/images/candlestick_chart_500_2024-12-27 13:05_to_2024-12-27 17:10.png
# Saved detected pattern to /content/detected_patterns/detected_candlestick_chart_500_2024-12-27 13:05_to_2024-12-27 17:10.png
# <PIL.Image.Image image mode=RGB size=800x575>
# 0: 480x640 (no detections), 724.9ms
# Speed: 3.3ms preprocess, 724.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
# No pattern detected in /content/images/candlestick_chart_500_2024-12-26 06:35_to_2024-12-26 08:30.png
# 0: 480x640 1 M_Head, 709.6ms
# Speed: 0.9ms preprocess, 709.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# Pattern detected in /content/images/candlestick_chart_500_2024-12-27 03:45_to_2024-12-27 09:40.png
# Saved detected pattern to /content/detected_patterns/detected_candlestick_chart_500_2024-12-27 03:45_to_2024-12-27 09:40.png
# <PIL.Image.Image image mode=RGB size=800x575>
# 0: 480x640 (no detections), 697.1ms
# Speed: 1.1ms preprocess, 697.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
# No pattern detected in /content/images/candlestick_chart_500_2024-12-27 13:45_to_2024-12-27 15:40.png
# 0: 480x640 1 W_Bottom, 726.1ms
# Speed: 1.1ms preprocess, 726.1ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# Pattern detected in /content/images/candlestick_chart_500_2024-12-27 00:35_to_2024-12-27 04:40.png
# Saved detected pattern to /content/detected_patterns/detected_candlestick_chart_500_2024-12-27 00:35_to_2024-12-27 04:40.png
# <PIL.Image.Image image mode=RGB size=800x575>
# 0: 480x640 (no detections), 760.7ms
# Speed: 1.0ms preprocess, 760.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
# No pattern detected in /content/images/candlestick_chart_500_2024-12-27 17:45_to_2024-12-27 19:40.png
# 0: 480x640 (no detections), 739.7ms
# Speed: 0.9ms preprocess, 739.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
# No pattern detected in /content/images/candlestick_chart_500_2024-12-26 18:35_to_2024-12-26 20:30.png
# 0: 480x640 (no detections), 436.5ms
# Speed: 0.9ms preprocess, 436.5ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# No pattern detected in /content/images/candlestick_chart_500_2024-12-27 15:45_to_2024-12-27 17:40.png
# 0: 480x640 (no detections), 444.7ms
# Speed: 1.0ms preprocess, 444.7ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# No pattern detected in /content/images/candlestick_chart_500_2024-12-26 14:35_to_2024-12-26 16:30.png
# 0: 480x640 1 W_Bottom, 447.4ms
# Speed: 1.0ms preprocess, 447.4ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# Pattern detected in /content/images/candlestick_chart_500_2024-12-26 02:35_to_2024-12-26 08:30.png
# Saved detected pattern to /content/detected_patterns/detected_candlestick_chart_500_2024-12-26 02:35_to_2024-12-26 08:30.png
# <PIL.Image.Image image mode=RGB size=800x575>
